# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Extracting data into Jupyter Notebook
df = pd.read_csv(r"D:\Personal\ELEVATE LABS\Task 5 29-04-2025\Titanic Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Splitting column "Name" into "FirstName" and "LastName"

df[["LastName", "FirstName"]] = df["Name"].str.split("," , expand = True)

# %%
# Using head function

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   LastName  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
# Splitting column "FirstName"  into "Title" and "FirstName"

df[["Title", "FirstName"]] = df["FirstName"].str.split('.', n=1, expand=True).fillna('')

# %%
# Using tail function

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  LastName  \
# 886    male  27.0      0      0      211536  13.00   NaN        S  Montvila
# 887  female  19.0      0      0      112053  30.00   B42        S    Graham
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S  Johnston
# 889    male  26.0      0      0      111369  30.00  C148        C      Behr
# 890    male  32.0      0      0      370376   7.75   NaN        Q    Dooley
#
#                      FirstName  Title
# ...

# %%
# Reordering columns
# Finding the Original Position of "Name"

original_index = df.columns.get_loc("Name")

# %%
# Dropping the "Name" Column

df.drop(columns = ["Name"], inplace = True)

# %%
# Inserting the New Columns at the Same Position

df.insert(original_index, "Title", df.pop("Title"))
df.insert(original_index + 1, "FirstName", df.pop("FirstName"))
df.insert(original_index + 2, "LastName", df.pop("LastName"))

# %%
# Dropping FName column

df.drop(columns = ["FName"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Dropping FName column
# ----> 3 df.drop(columns = ["FName"], inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Title  \
# 0            1         0       3     Mr
# 1            2         1       1    Mrs
# 2            3         1       3   Miss
# 3            4         1       1    Mrs
# 4            5         0       3     Mr
#
#                                 FirstName   LastName     Sex   Age  SibSp  \
# 0                             Owen Harris     Braund    male  22.0      1
# 1   John Bradley (Florence Briggs Thayer)    Cumings  female  38.0      1
# 2                                   Laina  Heikkinen  female  26.0      0
# 3           Jacques Heath (Lily May Peel)   Futrelle  female  35.0      1
# 4                           William Henry      Allen    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# Rounding of all fares to 2 decimals

df["Fare"] = df["Fare"].round(2)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Title  \
# 0            1         0       3     Mr
# 1            2         1       1    Mrs
# 2            3         1       3   Miss
# 3            4         1       1    Mrs
# 4            5         0       3     Mr
#
#                                 FirstName   LastName     Sex   Age  SibSp  \
# 0                             Owen Harris     Braund    male  22.0      1
# 1   John Bradley (Florence Briggs Thayer)    Cumings  female  38.0      1
# 2                                   Laina  Heikkinen  female  26.0      0
# 3           Jacques Heath (Lily May Peel)   Futrelle  female  35.0      1
# 4                           William Henry      Allen    male  35.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 0      0         A/5 21171   7.25   NaN        S
# 1      0          PC 17599  71.28   C85        C
# 2      0  STON/O2. 3101282   7.92   NaN        S
# 3      0            113803  53.10  C123        S
# ...

# %%
#Updating column names for consistent Format and Naming

df.columns = ['PassengerId', 'Survived', 'PClass', 'Title', 'FirstName', 'LastName',
       'Sex', 'Age', 'SibSp', 'ParCh', 'TicketNo', 'TicketFare', 'Cabin', 'Embarked']

# %%
# Checking information of the columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   PClass       891 non-null    int64
#  3   Title        891 non-null    object
#  4   FirstName    891 non-null    object
#  5   LastName     891 non-null    object
#  6   Sex          891 non-null    object
#  7   Age          714 non-null    float64
#  8   SibSp        891 non-null    int64
#  9   ParCh        891 non-null    int64
#  10  TicketNo     891 non-null    object
#  11  TicketFare   891 non-null    float64
#  12  Cabin        204 non-null    object
#  13  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 97.6+ KB

# %%
# Checking for any null values

df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# PClass           0
# Title            0
# FirstName        0
# LastName         0
# Sex              0
# Age            177
# SibSp            0
# ParCh            0
# TicketNo         0
# TicketFare       0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Filling null values in "Age" column with 0

df["Age"] = df["Age"].fillna(0)

# %%
# Filling null values in "Cabin" column with empty string

df["Cabin"] = df["Cabin"].fillna('')

# %%
# Filling null values in "Embarked" column with empty string

df["Embarked"] = df["Embarked"].fillna('')

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# PClass         0
# Title          0
# FirstName      0
# LastName       0
# Sex            0
# Age            0
# SibSp          0
# ParCh          0
# TicketNo       0
# TicketFare     0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Removing rows with no embarkment point

df = df[df['Embarked'] != '']

# %%
df
# Out:
#      PassengerId  Survived  PClass  Title  \
# 0              1         0       3     Mr
# 1              2         1       1    Mrs
# 2              3         1       3   Miss
# 3              4         1       1    Mrs
# 4              5         0       3     Mr
# ..           ...       ...     ...    ...
# 886          887         0       2    Rev
# 887          888         1       1   Miss
# 888          889         0       3   Miss
# 889          890         1       1     Mr
# 890          891         0       3     Mr
#
#                                   FirstName   LastName     Sex   Age  SibSp  \
# 0                               Owen Harris     Braund    male  22.0      1
# 1     John Bradley (Florence Briggs Thayer)    Cumings  female  38.0      1
# 2                                     Laina  Heikkinen  female  26.0      0
# 3             Jacques Heath (Lily May Peel)   Futrelle  female  35.0      1
# ...

# %%
# Finding some basic statistical values from the df

df.describe().T
# Out:
#              count        mean         std  min    25%     50%    75%     max
# PassengerId  889.0  446.000000  256.998173  1.0  224.0  446.00  668.0  891.00
# Survived     889.0    0.382452    0.486260  0.0    0.0    0.00    1.0    1.00
# PClass       889.0    2.311586    0.834700  1.0    2.0    3.00    3.0    3.00
# Age          889.0   23.740349   17.562609  0.0    6.0   24.00   35.0   80.00
# SibSp        889.0    0.524184    1.103705  0.0    0.0    0.00    1.0    8.00
# ParCh        889.0    0.382452    0.806761  0.0    0.0    0.00    0.0    6.00
# TicketFare   889.0   32.096839   49.697490  0.0    7.9   14.45   31.0  512.33

# %%
# Finding survival rate by passenger class

survival_by_class = df.groupby("PClass")["Survived"].mean()

print(survival_by_class)
# Out:
# PClass
# 1    0.626168
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
# Finding survival rate by embarkation point

survival_by_embarkment = df.groupby("Embarked")["Survived"].mean()

print(survival_by_embarkment)
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %%
# Finding survival rate by gender

survival_by_gender = df.groupby("Sex")["Survived"].mean()

print(survival_by_gender)
# Out:
# Sex
# female    0.740385
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Rouding off ages to integers

df.loc[:, "Age"] = df["Age"].round().astype(int)

# %%
df
# Out:
#      PassengerId  Survived  PClass  Title  \
# 0              1         0       3     Mr
# 1              2         1       1    Mrs
# 2              3         1       3   Miss
# 3              4         1       1    Mrs
# 4              5         0       3     Mr
# ..           ...       ...     ...    ...
# 886          887         0       2    Rev
# 887          888         1       1   Miss
# 888          889         0       3   Miss
# 889          890         1       1     Mr
# 890          891         0       3     Mr
#
#                                   FirstName   LastName     Sex   Age  SibSp  \
# 0                               Owen Harris     Braund    male  22.0      1
# 1     John Bradley (Florence Briggs Thayer)    Cumings  female  38.0      1
# 2                                     Laina  Heikkinen  female  26.0      0
# 3             Jacques Heath (Lily May Peel)   Futrelle  female  35.0      1
# ...

# %%
# Dividing ages into groups

df.loc[:, "AgeGroup"] = pd.cut(df["Age"], bins=[0, 10.5, 20, 30, 40, 50, 60, 70, 80], labels=["0-10", "11-20", "21-30", "31-40", "41-50", "51-60", "61-70", "71-80"])
# Out:
# C:\Users\Ankanee Chandra\AppData\Local\Temp\ipykernel_11064\3210904729.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, "AgeGroup"] = pd.cut(df["Age"], bins=[0, 10.5, 20, 30, 40, 50, 60, 70, 80], labels=["0-10", "11-20", "21-30", "31-40", "41-50", "51-60", "61-70", "71-80"])

# %%
df.head()
# Out:
#    PassengerId  Survived  PClass  Title  \
# 0            1         0       3     Mr
# 1            2         1       1    Mrs
# 2            3         1       3   Miss
# 3            4         1       1    Mrs
# 4            5         0       3     Mr
#
#                                 FirstName   LastName     Sex   Age  SibSp  \
# 0                             Owen Harris     Braund    male  22.0      1
# 1   John Bradley (Florence Briggs Thayer)    Cumings  female  38.0      1
# 2                                   Laina  Heikkinen  female  26.0      0
# 3           Jacques Heath (Lily May Peel)   Futrelle  female  35.0      1
# 4                           William Henry      Allen    male  35.0      0
#
#    ParCh          TicketNo  TicketFare Cabin Embarked AgeGroup
# 0      0         A/5 21171        7.25              S    21-30
# 1      0          PC 17599       71.28   C85        C    31-40
# 2      0  STON/O2. 3101282        7.92              S    21-30
# ...

# %%
# Finding survival rate by age

survival_by_age = df.groupby("AgeGroup")["Survived"].mean()

print(survival_by_age)
# Out:
# AgeGroup
# 0-10     0.587302
# 11-20    0.379310
# 21-30    0.363636
# 31-40    0.441558
# 41-50    0.392857
# 51-60    0.404762
# 61-70    0.176471
# 71-80    0.250000
# Name: Survived, dtype: float64
# C:\Users\Ankanee Chandra\AppData\Local\Temp\ipykernel_11064\701405510.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_by_age = df.groupby("AgeGroup")["Survived"].mean()

# %%
#Subplots for all above calculations

# Setting figure size for subplot
plt.figure(figsize = (15, 10))

# To display Survival Rate by Passenger Class
plt.subplot(2, 2, 1)  # Syntax: plt.subplot(no. of rows, no. of columns, position of the plot)
survival_by_class.plot(kind='bar', color=["#00008B", "#0000FF", "#4169E1"])
plt.title("Survival Rate by Passenger Class")
plt.ylabel("Survial Rate")

# To display Survival Rate by Embarkment Point
plt.subplot(2, 2, 2)
survival_by_embarkment.plot(kind='bar', color=["#006400", "#008000", "#228B22"])
plt.title("Survival Rate by Embarkment Point")
plt.ylabel("Survial Rate")

# To display Survival Rate by Gender
plt.subplot(2, 2, 3)
survival_by_gender.plot(kind='bar', color=["#8B0000", "#B22222", "#FF0000"])
plt.title("Survival Rate by Gender")
plt.ylabel("Survial Rate")

# To display HISTOGRAM
plt.subplot(2, 2, 4)
sns.histplot(x=survival_by_age.index, y=survival_by_age.values)
plt.xlabel("Age Group")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Age Group")
plt.show()

# %%
# Relation between the different variables with hues based on survival status

sns.pairplot(df, hue="Survived")  # Hue adds color based on survival status

plt.show()

# %%
# Finding age distribution among passengers

sns.histplot(df["Age"], bins = 25, kde = True, color = "#800080")
plt.title("Age Distribution of Titanic Passengers")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# Finding fare distribution

plt.boxplot(df["TicketFare"], vert = False)
plt.title("Fare Distribution")
plt.show()

# %%
passenger_count_by_embarkation = df["Embarked"].value_counts()
print(passenger_count_by_embarkation)
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Finding passenger distribution by embarkment point

plt.pie(passenger_count_by_embarkation, labels = passenger_count_by_embarkation.index, autopct="%.2f%%", explode=[0.05, 0.05, 0.05])
plt.title("Passenger Distribution By Embarkment Point")
plt.show()

# %%
df
# Out:
#      PassengerId  Survived  PClass  Title  \
# 0              1         0       3     Mr
# 1              2         1       1    Mrs
# 2              3         1       3   Miss
# 3              4         1       1    Mrs
# 4              5         0       3     Mr
# ..           ...       ...     ...    ...
# 886          887         0       2    Rev
# 887          888         1       1   Miss
# 888          889         0       3   Miss
# 889          890         1       1     Mr
# 890          891         0       3     Mr
#
#                                   FirstName   LastName     Sex   Age  SibSp  \
# 0                               Owen Harris     Braund    male  22.0      1
# 1     John Bradley (Florence Briggs Thayer)    Cumings  female  38.0      1
# 2                                     Laina  Heikkinen  female  26.0      0
# 3             Jacques Heath (Lily May Peel)   Futrelle  female  35.0      1
# ...

# %%
plt.figure(figsize=(16,5))
plt.scatter(df["TicketFare"], df["PClass"], zorder=3, c= df["Survived"]) 
plt.xlabel("Ticket Fare")
plt.ylabel("Passenger Class")
plt.colorbar()
plt.show()
